# %% [markdown]
# # LEVEL 3 -> TASK 2

# %%
# Task 2: Support Vector Machine (SVM)
# Dataset: Sentiment dataset.csv

# %%
# IMPORTING LIBRARIES
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 1. Load Dataset
df = pd.read_csv("Sentiment dataset.csv")

print("First 5 rows:")
print(df.head())

print("\nDataset Info:")
print(df.info())
# Out:
# First 5 rows:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# 2  2023      1   15    15
# 3  2023      1   15    18
# 4  2023      1   15    19
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB
# None

# %%
# 2. Handle Missing Data
print("\nMissing values:")
print(df.isnull().sum())

df.dropna(inplace=True)
# Out:
# Missing values:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
# 3. Encode Target Variable
le = LabelEncoder()
df['Sentiment'] = le.fit_transform(df['Sentiment'])

# %%
# 4. Remove extremely rare classes (important fix)
class_counts = df['Sentiment'].value_counts()
valid_classes = class_counts[class_counts > 1].index
df = df[df['Sentiment'].isin(valid_classes)]

# %%
# 5. Separate Features and Target
X = df['Text']
y = df['Sentiment']

# %%
# 6. Convert Text to Numerical (TF-IDF)
vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words='english',
    ngram_range=(1,2)
)

X_vect = vectorizer.fit_transform(X)

# %%
# 7. Train-Test Split (NO stratify to avoid error)
X_train, X_test, y_train, y_test = train_test_split(
    X_vect, y, test_size=0.2, random_state=42
)

# %%
# ------------------ MODEL 1: LINEAR KERNEL ------------------
model_linear = SVC(kernel='linear', class_weight='balanced', probability=True)
model_linear.fit(X_train, y_train)

y_pred_linear = model_linear.predict(X_test)
y_prob_linear = model_linear.predict_proba(X_test)

# ------------------ MODEL 2: RBF KERNEL ------------------
model_rbf = SVC(kernel='rbf', class_weight='balanced', probability=True)
model_rbf.fit(X_train, y_train)

y_pred_rbf = model_rbf.predict(X_test)
y_prob_rbf = model_rbf.predict_proba(X_test)

# %%
# ------------------ EVALUATION FUNCTION ------------------
def evaluate(y_test, y_pred, y_prob, name):
    print(f"\n{name} Results:")

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

    # AUC Score (handles multiclass safely)
    auc = roc_auc_score(y_test, y_prob, multi_class='ovr')

    print("Accuracy :", accuracy)
    print("Precision:", precision)
    print("Recall   :", recall)
    print("F1 Score :", f1)
    print("AUC      :", auc)

# %%
# 8. Evaluate Models
evaluate(y_test, y_pred_linear, y_prob_linear, "Linear Kernel")
evaluate(y_test, y_pred_rbf, y_prob_rbf, "RBF Kernel")
# Out:
# Linear Kernel Results:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 # 8. Evaluate Models
# ----> 2 evaluate(y_test, y_pred_linear, y_prob_linear, "Linear Kernel")
#       3 evaluate(y_test, y_pred_rbf, y_prob_rbf, "RBF Kernel")
#
# Cell In[52], line 11, in evaluate(y_test, y_pred, y_prob, name)
#       8 f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
#      10 # AUC Score (handles multiclass safely)
# ---> 11 auc = roc_auc_score(y_test, y_prob, multi_class='ovr')
#      13 print("Accuracy :", accuracy)
#      14 print("Precision:", precision)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:635, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     633     if multi_class == "raise":
#     634         raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 635     return _multiclass_roc_auc_score(
#     636         y_true, y_score, labels, multi_class, average, sample_weight
#     637     )
#     638 elif y_type == "binary":
#     639     labels = np.unique(y_true)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:752, in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     750     classes = _unique(y_true)
#     751     if len(classes) != y_score.shape[1]:
# --> 752         raise ValueError(
#     753             "Number of classes in y_true not equal to the number of "
#     754             "columns in 'y_score'"
#     755         )
#     757 if multi_class == "ovo":
#     758     if sample_weight is not None:
#
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'
